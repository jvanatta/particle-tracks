# %% [markdown]
# #### Exercise 1:

# %% [markdown]
# #### (a), (b)

# %%
x, y = loadtxt('radioactivedecay.dat', unpack=True, usecols=(0,1))

plot(x, log(y), 'b', marker = '*', linestyle = "")
xlabel("time")
ylabel("ln(N)")
show()

# %% [markdown]
# #### (d)

# %%
from CurveFitting import *
import numpy as np
m, b, merr, berr = LinearLeastSquaresFit(x+1, log(y))

# %%
lab = "y = %.4fx + %.4f" % (m,b)

plot(x+1, log(y), 'b', marker = '$*$', linestyle = "")

plot(x+1, (x+1)*m + b, 'r', linestyle = "--", label = lab)
legend(loc='upper right')
axis("tight")
xlabel("time")
ylabel("ln(N)")
show()

print "m = %.4f ± %.4f" % (m,merr)
print "b = %.4f ± %.4f" % (b,berr)
# Out:
# m = -0.3166 ± 0.0056
# b = 2.6133 ± 0.0538

# %% [markdown]
# #### Curve fitting example 1

# %%
from scipy.optimize import curve_fit
def func(x,a,b,c):
    return (a*x**2 + b*x + c)
x = np.arange(6.)
y = array([-1.78, 4.09, 8.85, 17.9, 26.1, 35.2])
yerr = array([.46, .658, .528, 1.34, 1.09, .786])

p0 = [1.0, 3.0, -2.]

popt, pcov = curve_fit(func, x, y, p0, yerr)

# %%
punc = zeros(len(popt))
for i in arange(0, len(popt)):
    punc[i] = sqrt(pcov[i,i])
    
print "opt param: ", popt
print "unc of param: ", punc
# Out:
# opt param:  [ 0.61500361  4.33082898 -1.66737444]
# unc of param:  [ 0.11813261  0.57818057  0.50099218]

# %%
errorbar(x, y, yerr, fmt='r*')
fitresult = func(x, popt[0], popt[1], popt[2])
plot(x, fitresult, 'b-')
show()

# %% [markdown]
# #### Curve Fitting Ex 2

# %%
waveform_1 = load('waveform_1.npy')
t = np.arange(len(waveform_1))

plot(t, waveform_1)
xlabel("Time (ns)")
ylabel("Intensity (bins)")
show()

# %%
def model(t, B, A, mu, sigma):
    return B + A*exp( - ((t-mu)/sigma)**2)
x0 = array([3., 30., 15., 1])

popt, pcov = curve_fit(model, t, waveform_1, x0)
plot(t, waveform_1, label="data")
plot(t, model(t, popt[0], popt[1], popt[2], popt[3]), label="fit", linewidth=2)
legend(loc="best")
show()

# %% [markdown]
# #### Exercise 2.

# %% [markdown]
# #### (a)

# %%
waveform_2 = load('waveform_2.npy')
t = np.arange(len(waveform_2))

plot(t, waveform_2)
xlabel("Time (ns)")
ylabel("Intensity (bins)")
show()

# %% [markdown]
# #### (b), (c)

# %%
def model(t, B1, A1, mu1, sigma1, B2, A2, mu2, sigma2, B3, A3, mu3, sigma3):
    return (B1 + A1*exp( - ((t-mu1)/sigma1)**2)) + (B2 + A2*exp( - ((t-mu2)/sigma2)**2)) + (B3 + A3*exp( - ((t-mu3)/sigma3)**2))

x0 = array([3., 15., 25., 1, 3., 25., 15., 1, 3., 33., 30., 1])

popt, pcov = curve_fit(model, t, waveform_2, x0)

print "optimal parameters: "
print popt
print "uncertainty of parameters (covariant matrix): "
for i in pcov:
    print i
# Out:
# optimal parameters:
# [ -3.98664235e+04   9.55794186e+00   2.31151880e+01   2.96743619e+00
#   -1.25891787e+04   2.35862752e+01   1.65964659e+01   2.43359217e+00
#    5.24580668e+04   5.27898869e+00   2.89646880e+01   3.18703190e+00]
# uncertainty of parameters (covariant matrix):
