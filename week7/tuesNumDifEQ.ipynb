# %%
g = 9.81
l = .5
th0 = 20.*pi/180
t = arange(0., 10.+.01, .01)
theta_app = lambda t: th0 * cos(sqrt(g/l)*t)
    
plot(t,theta_app(t))
show()

# %%
def deriv(theta_current, t):
    g = 9.8
    l = .5
    theta = theta_current[0]
    omega = theta_current[1]
    dtheta = omega
    domega = -(g/l)*sin(theta)
    return array( [dtheta, domega] )

# %%
from scipy.integrate import odeint

t = arange(0., 10.+.01, .01)
omega0 = 0.
theta_init = array([th0, omega0])
theta = odeint(deriv, theta_init, t)

# %%
plot(t, theta_app(t), 'b-')
plot(t, theta[:,0], 'r:')
show()

# %%
th0 = 50.*pi/180


theta_init = array([th0, omega0])
theta = odeint(deriv, theta_init, t)

plot(t, theta_app(t), 'b-')
plot(t, theta[:,0], 'r:')
show()

# %% [markdown]
# #### Ex 1

# %%
g = 9.81
l = .5
th0 = 20.*pi/180
t = arange(0., 10.+.01, .01)
theta_app = lambda t: th0 * cos(sqrt(g/l)*t)
    
def deriv(theta_current, t):
    g = 9.8
    l = .5
    theta = theta_current[0]
    omega = theta_current[1]
    dtheta = omega
    domega = -(g/l)*sin(theta)
    return array( [dtheta, domega] )

from scipy.integrate import odeint

t = arange(0., 10.+.01, .01)
omega0 = 0.
theta_init = array([th0, omega0])
theta = odeint(deriv, theta_init, t)

# %%
for x in range(0,180+1,30):
    th0 = x*pi/180.

    theta_init = array([th0, omega0])
    theta = odeint(deriv, theta_init, t)

    plot(t, theta_app(t), 'b-')
    plot(t, theta[:,0], 'r--')
show()

# %%
th0 = .95*pi
theta_init = array([th0, omega0])
theta = odeint(deriv, theta_init, t, rtol=1.5e-13, atol=1.5e-13)

plot(t, theta_app(t), 'b-') #approx
plot(t, theta[:,0], 'r--') #numeric
plot(t, theta[:,1], 'g--')
show()
#odeint?

# %%
g = 9.81
r = .5
m = 1.
#h = lambda th: 

    
height = r* (1 - cos(theta[:,0]))
print height
omega = theta[:,1]
#E = lambda om, th: m*g (r*l-l*cos(th)) + .5 * m * om**2 * r
energy = m*g*height + .5 * m * (r * omega)**2


#plot(t, m*g*height ,'r--')
plot(t, energy ,'g')
#plot(t, .5*m*r*omega**2 ,'b--')
show()
# Out:
# [ 0.99384417  0.99383217  0.99379608 ...,  0.5017075   0.5322531
#   0.56170811]
