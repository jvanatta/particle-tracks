# %%
import numpy.random

print numpy.random.random(5)
numpy.random.seed(4242)
print numpy.random.random(5)
# Out:
# [ 0.54288911  0.93149559  0.05843166  0.29945052  0.71745907]
# [ 0.32494949  0.94041458  0.91400794  0.28650938  0.78180262]

# %%
x = arange(0., pi+.01, .01)
f = lambda x: sin(x)/2
F = lambda x: (cos(0)-cos(x))/2.
    
plot(x,f(x), label = "True distribution", lw=3)
plot(x, F(x), label="Cumulative fuction", lw=3)
legend(loc='best')
show()

# %%
N = 10000
z = numpy.random.random_sample(N)

Finv = lambda z: arccos(cos(0)-2*z)
xsamples = Finv(z)

hist(xsamples, 50, normed=True, label="Sampled distribution")
plot(x, f(x), label="True Distribution", lw=3, color='red') 


xlim(0,pi)
ylim(0,.7)
legend(loc='best')
show()

# %% [markdown]
# #### Exercise 1. Exponential function - analytic

# %%
x = np.arange(0,5.01, .01)
lam = 1
f = lambda x: lam*exp(-lam*x)
F = lambda x: 1-exp(-lam*x)
Finv = lambda y: -log(1-y)/lam
    
t = arange(.01,5,.01)
plot(t, f(t))
plot(t, F(t), linewidth=5)
show()

N = 10000
z = numpy.random.random_sample(N)

xsamples = Finv(z)

hist(xsamples, 50, normed=True, label="Sampled Distribution")
plot(x, f(x), label="True Distribution", lw=3, color='red')
legend(loc='best')

plt.show()

# %% [markdown]
# #### Exercise 2. Exponential function - numeric

# %%
N = 10000
z = numpy.random.random_sample(N)
t = arange(.01, 5, .01)



cumul  = cumsum(f(t)) / (sum(f(t)))

ss = cumul.searchsorted(z)

hist(t[ss], 50, normed=True, label="Sampled Distribution")
plot(t, f(t), label="True Distribution", lw=3, color='red')
legend(loc='best')
show()

# %% [markdown]
# #### (c) Reusable function

# %%
def distribute1D(x, probfunc, N):
    """takes any numerical distribution prob, on the interval defined by the array x,
    and returns an array of N sampled values that are statiscally the same as the input data."""
    
    z = numpy.random.random_sample(N)
    cumul  = cumsum(probfunc) / (sum(probfunc))
    ss = cumul.searchsorted(z)
      
    return x[ss]



hist(distribute1D(t, f(t), 10000), 50, normed=True, label="Sampled Distribution")
#plot(t, f(t), label="True Distribution", lw=3, color='red')
legend(loc='best')
show()

# %% [markdown]
# #### Exercise 3

# %%
x = arange(-.2, .2+.01, .001)
A = 1
a = 10E-6
lamb = 632.8E-9
L = 1
d = 15E-6

N = 10000

Ids = lambda x: A**4*(sinc(a*x/(lamb*L)))**2 * (cos(2*pi*d*x/(lamb*L)))**2
plot (x, Ids(x))
axis("tight")
show()

# %%
N = 1
n,b,p = hist(distribute1D(x, Ids(x), N), 100, normed=True, label="Sampled Distribution")
plot(x, Ids(x)*max(n), label="True Distribution", lw=3, color='red', linestyle="--", linewidth=2)
legend(loc='upper right')
#axis("tight")
show()

# %%
N = 10
n,b,p = hist(distribute1D(x, Ids(x), N), 100, normed=True, label="Sampled Distribution")
plot(x, Ids(x)*max(n), label="True Distribution", lw=3, color='red', linestyle="--", linewidth=2)
legend(loc='upper right')
#axis("tight")
show()

# %%
N = 100
n,b,p = hist(distribute1D(x, Ids(x), N), 100, normed=True, label="Sampled Distribution")
plot(x, Ids(x)*max(n), label="True Distribution", lw=3, color='red', linestyle="--", linewidth=2)
legend(loc='upper right')
#axis("tight")
show()

# %%
N = 1000
n,b,p = hist(distribute1D(x, Ids(x), N), 100, normed=True, label="Sampled Distribution")
plot(x, Ids(x)*max(n), label="True Distribution", lw=3, color='red', linestyle="--", linewidth=2)
legend(loc='upper right')
#axis("tight")
show()

# %%
N = 10000
n,b,p = hist(distribute1D(x, Ids(x), N), 100, normed=True, label="Sampled Distribution")
plot(x, Ids(x)*max(n), label="True Distribution", lw=3, color='red', linestyle="--", linewidth=2)
legend(loc='upper right')
#axis("tight")
show()
