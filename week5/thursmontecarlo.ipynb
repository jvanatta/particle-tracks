# %%
f = lambda x: x**(.5) + sin(x)
x = arange(0.,15., .001)
myplot = plot(x, f(x), lw=3)
ylabel(r'$x^{1/2} + \sin(x)$', fontsize=20)
xlabel(r"$x$", fontsize = 20)
xlim(0., 15.)

show()

# %%
xmin = 1.7
xmax = 12.4

N = 10000
samples_x = xmin + (xmax-xmin)*random_sample(N)
samples_y = ymin + (ymax - ymin) * random_sample(N)

#find maximum for bb
subx = x[logical_and((x > xmin), (x < xmax))]
ymax = max(f(subx))*1.05
ymin = 0.

myplot = plot(x,f(x), lw=3)
xlim(0.,15.)

plot(samples_x[1:400], samples_y[1:400], ',')

plot([xmin,xmin], [ymin, ymax], color = 'k', linestyle = '--')
plot([xmax,xmax], [ymin, ymax], color = 'k', linestyle = '--')
plot([xmin,xmax], [ymax, ymax], color = 'k', linestyle = '--')
show()

# %%
newmask = (samples_y < f(samples_x))
sum(newmask)

myplot = plot(x,f(x), lw=3)
xlim(0.,15.)

plot(samples_x[1:400], samples_y[1:400], 'g.')
plot(samples_x[newmask[:400]], samples_y[newmask[:400]], 'r.')

plot([xmin,xmin], [ymin, ymax], color = 'k', linestyle = '--')
plot([xmax,xmax], [ymin, ymax], color = 'k', linestyle = '--')
plot([xmin,xmax], [ymax, ymax], color = 'k', linestyle = '--')
show()

# %%
# Out:
# 26.6484363126

# %%
I = (xmax - xmin) * (ymax - ymin) * sum(newmask)/newmask.size
print I

Iana  = lambda x: (2./3.)*x**(3./2.) - cos(x)
Iexact = Iana(xmax) - Iana(xmin)
Ierr = 100*(Iexact - I) / Iexact
print "I_exact =", Iexact
print "I_MC =", I
print "Error of MC =", Ierr, "%"
# Out:
# I_exact = 26.5172145362
# I_MC = 26.6484363126
# Error of MC = -0.494855054192 %

# %% [markdown]
# Exercise 1
# ----

# %%
#reference version

f = lambda x: x**(.5) + sin(x)
x = arange(0.,15., .001)

#integration limits
xmin = 1.7
xmax = 12.4

#bounding box y limits
subx = x[logical_and((x > xmin), (x < xmax))]
ymax = max(f(subx))*1.05
ymin = 0.

N = float(1E7)
samples_x = xmin + (xmax-xmin)*random_sample(N)
samples_y = ymin + (ymax - ymin) * random_sample(N)


newmask = (samples_y < f(samples_x))
I = (xmax - xmin) * (ymax - ymin) * sum(newmask)/newmask.size
Iana  = lambda x: (2./3.)*x**(3./2.) - cos(x)
Iexact = Iana(xmax) - Iana(xmin)
Ierr = 100*(Iexact - I) / Iexact
print "I_exact =", Iexact
print "I_MC =", I
print "Error of MC =", Ierr, "%"
# Out:
# I_exact = 26.5172145362
# I_MC = 26.5169443824
# Error of MC = 0.00101878629758 %

# %% [markdown]
# Exercise 2: Sample Mean Method
# ----

# %%
f = lambda x: x**(.5) + sin(x)
x = arange(0.,15., .001)

#integration limits
xmin = 1.7
xmax = 12.4

#bounding box y limits
subx = x[logical_and((x > xmin), (x < xmax))]
ymax = max(f(subx))*1.05
ymin = 0.

N = float(1E4)
samples_x = xmin + (xmax-xmin)*random_sample(N)
guess_y = f(samples_x)
avg = np.average(guess_y)
print "average value is", avg
I = avg*(xmax-xmin)
print "I_MC =", I


Iana  = lambda x: (2./3.)*x**(3./2.) - cos(x)
Iexact = Iana(xmax) - Iana(xmin)
Ierr = 100*(Iexact - I) / Iexact
print "I_exact =", Iexact
print "I_MC =", I
print "Error of MC =", Ierr, "%"
# Out:
# average value is 2.48265924892
# I_MC = 26.5644539634
# I_exact = 26.5172145362
# I_MC = 26.5644539634
# Error of MC = -0.178146264804 %

# %% [markdown]
# (b)

# %%
avgraph = np.ones(x.size)
avgraph *= avg

myplot = plot(x, f(x), lw=3)
plot(x,avgraph)
ylabel(r'$x^{1/2} + \sin(x)$', fontsize=20)
xlabel(r"$x$", fontsize = 20)
xlim(0., 15.)
show()

# %% [markdown]
# (c) Comparison to exact

# %%
Iana  = lambda x: (2./3.)*x**(3./2.) - cos(x)
Iexact = Iana(xmax) - Iana(xmin)
Ierr = 100*(Iexact - I) / Iexact
print "I_exact =", Iexact
print "I_MC =", I
print "Error of MC =", Ierr, "%"
# Out:
# I_exact = 26.5172145362
# I_MC = 26.485422697
# Error of MC = 0.119891322508 %

# %% [markdown]
# The sample mean method seems to be about 10 times more accurate than the hit or miss method for the same sample size

# %% [markdown]
# Multi Dimensional Integrals
# -----

# %%
fxyz = lambda x,y,z: sqrt(x**2 + y**2 + z**2)
N = 1e6
L = 1.; W = 1.; H = 1.
x = L*random_sample(N); y = W*random_sample(N); z = H*random_sample(N);

IntMC = (L*W*H/N)*sum(fxyz(x,y,z))
print IntMC
# Out:
# 0.96057218151

# %%
N = 1E5
fsph = lambda r,phi: (cos(phi)/r**3)
phiMax = 2*pi; thetaMax = pi; rMax = 1;
phi = phiMax*random_sample(N)
theta = thetaMax*random_sample(N)
r = rMax*random_sample(N)
Integral_MC = (phiMax*thetaMax*rMax/N)*sum(fsph(r,phi)*r**2*sin(theta))
print Integral_MC
# Out:
# -6.28546674323
