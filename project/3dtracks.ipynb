# %%
import numpy as np
import matplotlib.pyplot as plt

from mpl_toolkits.mplot3d import Axes3D

class Event(object):

    def __init__(self, id):
        self.id = id
        self.edat = []
        self.traj = []
        self.orphans = []
                                       
    def getID(self):
        return self.id
    
    def getData(self):
        return self.edat
                    
    def getTrajectories(self):
        return self.traj
    
    def getOrphans(self):
        return self.orphans
            
    def printData(self):
        for v in self.edat:
            print v.toString()
    
    def addVoxel(self, d):
        self.edat.append(Voxel([int(d[0]), int(d[1]), int(d[2]), int(d[3])] , int(d[4])))
            
    def popNeighbors(self, vox):
        poplist = []
        for v in listNeighbors(self.edat, vox):
            poplist.append(self.edat.pop(self.edat.index(v)))
        return poplist
    
    def makeTrajectories(self, gradthresh, dirthresh):
        self.edat = sorted(self.edat, key = lambda v: v.getVal(), reverse=True)
        
        maxlen = len(self.edat)
        x = 0
        
        while len(self.edat) > 0:
            vox = self.edat.pop(0)
            newTraj = Trajectory(vox)
            self.traj.append(newTraj)
            
            #breaks when there are no more candidates being generated
            while True:
                
                candidates = []
                rejects = []
                chosen = []
                
                neigh = self.popNeighbors(vox)
                candidates.extend(neigh)
                
                grad = getGradient(vox, neigh)
                
                for v in candidates:
                    #print v.toString()
                    #print grad[v]
                    thresh = vox.getVal() * gradthresh
                    if grad[v][1] <= thresh:
                        if newTraj.checkDir(grad[v][0], dirthresh):
                            #voxel matches trajectory
                            chosen.append(v)
                        else:
                            rejects.append(v)
                    else:
                        #print "reject grd", grad[v][1], thresh
                        rejects.append(v)
                
                #no new chosen, time to stop
                if len(chosen) == 0:
                    self.edat.extend(rejects)
                    break
                
                #find the lowest gradient of the neighbors. that will be our new tail
                min = 1000000
                lowestgrad = None
                for v in chosen:
                    if grad[v][1] < min:
                        min = grad[v][1]
                        lowestgrad = v        
                vox = chosen.pop(chosen.index(lowestgrad))
                newTraj.addSpine(vox)
                
                #add the rest of the voxels that match gradient and direction but are not best
                for v in chosen:
                    newTraj.addFlesh(v)
                
                #recycle unused voxels            
                self.edat.extend(rejects)
            #end of chained tail loop
            
            self.edat = sorted(self.edat, key = lambda v: v.getVal(), reverse=True)
            
        #get the orphans
        for t in reversed(self.traj):
            if len(t.getSpine()) == 1:
                self.orphans.extend(t.getMembers())
                self.traj.remove(t)
        
    def mergeTrajectories(self, mergethresh):
        counter = 0
        numtraj = len(self.traj)
        for x in range(numtraj):
            t2 = self.traj.pop(0)
            tdir = t2.getDir()
            
            merged = False
            for i in range(numtraj):
                if i >= len(self.traj):
                    break
                t = self.traj[i]
                if t.checkDir(tdir, .01) and (neighborCheck(t.getHead(), t2.getHead()) or neighborCheck(t.getTail(), t2.getHead())
                                              or neighborCheck(t.getHead(), t2.getTail()) or neighborCheck(t.getTail(), t2.getTail())):
                    t.merge(t2)
                    merged = True
                    counter += 1
                    break
            if not merged:
                self.traj.append(t2)

        numtraj = len(self.traj)
        for x in range(numtraj):
            t2 = self.traj.pop(0)
            tdir = t2.getDir()
            
            merged = False
            for i in range(numtraj):
                if i >= len(self.traj):
                    break
                t = self.traj[i]
                if t.checkDir(tdir, mergethresh) and (neighborCheck(t.getHead(), t2.getHead()) or neighborCheck(t.getTail(), t2.getHead())
                                              or neighborCheck(t.getHead(), t2.getTail()) or neighborCheck(t.getTail(), t2.getTail())):
                    t.merge(t2)
                    merged = True
                    counter += 1
                    print "merged:", i,x
                else:
                    print "failed to merge:", i,x
            if not merged:
                print "failed to merge:", i,x
                self.traj.append(t2)
        return counter
        
class Trajectory(object):
    def __init__(self, vox):
        self.du = 0.
        self.dv = 0.
        self.dw = 0.
        self.directions = []
        self.flesh = []
        self.spine = [vox]
        self.tail = vox
    
    def addFlesh(self, vox):
        self.flesh.append(vox)
        
    def addSpine(self, vox):
        self.spine.append(vox)
        self.tail = vox
        self.directions.append(getGradient(self.spine[-2], [self.spine[-1]])[self.spine[-1]][0])
        self.du = sum([v[0] for v in self.directions]) / float(len(self.directions))
        self.dv = sum([v[1] for v in self.directions]) / float(len(self.directions))
        self.dw = sum([v[2] for v in self.directions]) / float(len(self.directions))
    
    def merge(self, tra):
        for v in tra.getSpine():
            self.addSpine(v)
        for v in tra.getFlesh():
            self.addFlesh(v)

    def getDir(self):
        return self.du,self.dv,self.dw
        
    def getTail(self):
        return self.spine[-1]
    
    def getHead(self):
        return self.spine[0]
    
    def getFlesh(self):
        return self.flesh
    
    def getSpine(self):
        return self.spine
    
    def getMembers(self):
        all = []
        all.extend(self.flesh)
        all.extend(self.spine)
        return all
    
    def checkDir(self, (vdu, vdv, vdw), dirthresh):
        
        if self.du == 0 and self.dv == 0 and self.dw ==0:
            return True
        
        err = (self.du - vdu)**2 + (self.dv - vdv)**2 + (self.dw - vdw)**2
        if err > dirthresh:
            #print "reject dir:", err
            return False
        return True
    
    def toString(self):
        s = str(self.du) + ", " + str(self.dv) + ", " + str(self.dw) + "\n"
        s += str(len(self.spine)) + " , " + str(len(self.flesh)) + "\n---"
        
        """
        for v in self.spine:
            s += v.toString() + ",  "
        s += "\n---\n"
        for v in self.flesh:
            s += v.toString() + ",  "
        s += "\n.............\n"
        """
        return s
        
class Voxel(object):
    def __init__(self, idarray, adc):
        self.id = (idarray[0], idarray[1], idarray[2], idarray[3])
        self.adc = adc
        
    def getID(self):
        return self.id
    
    def getVal(self):
        return self.adc
    
    def toString(self):
        return str(self.id) + "  " + str(self.adc)
          
def listNeighbors(li, vox):
        ne = []
        q = vox.getID()
        if q[1]%2 == 1:
            nmap = {
                (q[0], q[1], q[2]-1, q[3]), (q[0], q[1]-1, q[2], q[3]), (q[0], q[1]-1, q[2]+1, q[3]),
                (q[0], q[1], q[2]+1, q[3]), (q[0], q[1]+1, q[2]+1, q[3]), (q[0], q[1]+1, q[2], q[3]),
                
                (q[0], q[1], q[2], q[3]-1), (q[0], q[1], q[2]-1, q[3]-1), (q[0], q[1]-1, q[2], q[3]-1),
                (q[0], q[1]-1, q[2]+1, q[3]-1), (q[0], q[1], q[2]+1, q[3]-1), (q[0], q[1]+1, q[2]+1, q[3]-1),
                (q[0], q[1]+1, q[2], q[3]-1),
                
                (q[0], q[1], q[2], q[3]+1), (q[0], q[1], q[2]-1, q[3]+1), (q[0], q[1]-1, q[2], q[3]+1),
                (q[0], q[1]-1, q[2]+1, q[3]+1), (q[0], q[1], q[2]+1, q[3]+1), (q[0], q[1]+1, q[2]+1, q[3]+1),
                (q[0], q[1]+1, q[2], q[3]+1)
                }
        else:
            nmap = {
                (q[0], q[1], q[2]-1, q[3]), (q[0], q[1]-1, q[2], q[3]), (q[0], q[1]-1, q[2]-1, q[3]),
                (q[0], q[1], q[2]+1, q[3]), (q[0], q[1]+1, q[2]-1, q[3]), (q[0], q[1]+1, q[2], q[3]),
                
                (q[0], q[1], q[2], q[3]-1), (q[0], q[1], q[2]-1, q[3]-1), (q[0], q[1]-1, q[2], q[3]-1),
                (q[0], q[1]-1, q[2]-1, q[3]-1), (q[0], q[1], q[2]+1, q[3]-1), (q[0], q[1]+1, q[2]-1, q[3]-1),
                (q[0], q[1]+1, q[2], q[3]-1),
                
                (q[0], q[1], q[2], q[3]+1), (q[0], q[1], q[2]-1, q[3]+1), (q[0], q[1]-1, q[2], q[3]+1),
                (q[0], q[1]-1, q[2]-1, q[3]+1), (q[0], q[1], q[2]+1, q[3]+1), (q[0], q[1]+1, q[2]-1, q[3]+1),
                (q[0], q[1]+1, q[2], q[3]+1)
                }
        for v in li:
            if v.getID() in nmap:
                unique = True
                for n in ne:
                    if v.getID() == n.getID():
                        unique = False
                        print "**Error: Duplicate voxel**", v.getID()
                if unique:        
                    ne.append(v)    
        return ne
    
def neighborCheck(avox, bvox):
    if len(listNeighbors([avox], bvox)) == 1:
        return True
    else: return False
    

def voxelsToArray(li):
    le = len(li)
    earr = [np.zeros(le), np.zeros(le), np.zeros(le), np.zeros(le), np.zeros(le)]
    for i, v in enumerate(li):
        earr[0][i] = v.getID()[0]
        earr[1][i] = v.getID()[1]
        earr[2][i] = v.getID()[2]
        earr[3][i] = v.getID()[3]
        earr[4][i] = v.getVal()
    return earr
    
def plotEvent(ev, filename):

    fig = plt.figure(1)
    ax = fig.add_subplot(1,1,1, projection = '3d')
    
    colors = ["red", "orange", "yellow", "green", "blue", "purple", "pink"]
    for i, t in enumerate(ev.getTrajectories()):
        evda = voxelsToArray(t.getSpine())
        
        #tcolor = int(i%2), int(i%3%2), int(i%5%2), 1
        #if tcolor == (1,1,1,1):
        #   tcolor = .5,.5,.5,1
        if i > 6:
            tcolor = 'gray'
        else :
            tcolor = colors[i]
        
        p = ax.scatter(evda[1], evda[2], evda[3], s=1.5*evda[4], linewidth=0, color=tcolor)
    
    #plt.xlim(20, 40)
    #plt.ylim(20, 40)
    
    
    ax.set_xlabel('Row')
    ax.set_ylabel("Column")
    ax.set_zlabel('Bucket')
    
    #plt.savefig(filename)
    plt.show()
    plt.close()
    
    
def getGradient(vox, neigh):
    grad = dict()
    for v in neigh:
        
        dE = vox.getVal() - v.getVal()
        
        du = vox.getID()[1] - v.getID()[1]
        dv = vox.getID()[2] - v.getID()[2]
        dw = vox.getID()[3] - v.getID()[3]
        
        grad[v] = (du,dv,dw), dE
    #print "------"
    #print len(grad)
    #print "---..--"
    return grad

# %%
#setup and parse
evlist = []
evcounter = 0
datain = open('niffte_data.txt', 'r')

for i, line in enumerate (datain):
    if line.startswith('#'):
        evlist.append(Event(evcounter))
        evcounter += 1
    else:
        s = np.fromstring(line, sep=" ")
        evlist[-1].addVoxel(s)
        
datain.close()

# %% [markdown]
# ### Settings

# %%
gradthreshold = .75
dirthreshold = 3.1
mthresh = .5
run = evlist[28]

oldlen = len(run.getData())

run.makeTrajectories(gradthreshold, dirthreshold)
nummerged = run.mergeTrajectories(mthresh)


print ".....\n"
alltraj = run.getTrajectories()

alllen = 0
for t in alltraj:
    print t.toString()
    alllen += len(t.getMembers())

print "num trajectories:", len(alltraj)
print "old length", oldlen
print "all length", alllen
print "orp length", len(run.getOrphans())
print "merged trj", nummerged
print "new length", len(run.getData())
# Out:
# failed to merge: 0 0
# failed to merge: 1 0
# failed to merge: 2 0
# failed to merge: 3 0
# failed to merge: 4 0
# failed to merge: 5 0
# merged: 6 0
# failed to merge: 7 0
# failed to merge: 8 0
# failed to merge: 9 0
# failed to merge: 10 0
# failed to merge: 0 1
# failed to merge: 1 1
# failed to merge: 2 1
# failed to merge: 3 1
# failed to merge: 4 1
# failed to merge: 5 1
# failed to merge: 6 1
# failed to merge: 7 1
# failed to merge: 8 1
# failed to merge: 9 1
# failed to merge: 10 1
# failed to merge: 0 2
# failed to merge: 1 2
# failed to merge: 2 2
# failed to merge: 3 2
# failed to merge: 4 2
# failed to merge: 5 2
# failed to merge: 6 2
# failed to merge: 7 2
# failed to merge: 8 2
# failed to merge: 9 2
# failed to merge: 10 2
# failed to merge: 0 3
# failed to merge: 1 3
# failed to merge: 2 3
# failed to merge: 3 3
# failed to merge: 4 3
# failed to merge: 5 3
# failed to merge: 6 3
# failed to merge: 7 3
# failed to merge: 8 3
# failed to merge: 9 3
# failed to merge: 10 3
# failed to merge: 0 4
# failed to merge: 1 4
# failed to merge: 2 4
# failed to merge: 3 4
# failed to merge: 4 4
# merged: 5 4
# failed to merge: 6 4
# failed to merge: 7 4
# failed to merge: 8 4
# failed to merge: 9 4
# failed to merge: 0 5
# failed to merge: 1 5
# failed to merge: 2 5
# failed to merge: 3 5
# failed to merge: 4 5
# failed to merge: 5 5
# failed to merge: 6 5
# failed to merge: 7 5
# failed to merge: 8 5
# failed to merge: 9 5
# failed to merge: 0 6
# failed to merge: 1 6
# failed to merge: 2 6
# failed to merge: 3 6
# failed to merge: 4 6
# failed to merge: 5 6
# failed to merge: 6 6
# failed to merge: 7 6
# failed to merge: 8 6
# failed to merge: 9 6
# failed to merge: 0 7
# failed to merge: 1 7
# failed to merge: 2 7
# failed to merge: 3 7
# failed to merge: 4 7
# failed to merge: 5 7
# failed to merge: 6 7
# failed to merge: 7 7
# failed to merge: 8 7
# failed to merge: 9 7
# failed to merge: 0 8
# failed to merge: 1 8
# failed to merge: 2 8
# failed to merge: 3 8
# failed to merge: 4 8
# failed to merge: 5 8
# failed to merge: 6 8
# failed to merge: 7 8
# failed to merge: 8 8
# failed to merge: 9 8
# failed to merge: 0 9
# failed to merge: 1 9
# failed to merge: 2 9
# failed to merge: 3 9
# failed to merge: 4 9
# failed to merge: 5 9
# failed to merge: 6 9
# failed to merge: 7 9
# failed to merge: 8 9
# failed to merge: 9 9
# failed to merge: 0 10
# failed to merge: 1 10
# failed to merge: 2 10
# failed to merge: 3 10
# failed to merge: 4 10
# failed to merge: 5 10
# failed to merge: 6 10
# failed to merge: 7 10
# failed to merge: 8 10
# failed to merge: 9 10
# failed to merge: 0 11
# failed to merge: 1 11
# failed to merge: 2 11
# failed to merge: 3 11
# failed to merge: 4 11
# failed to merge: 5 11
# failed to merge: 6 11
# failed to merge: 7 11
# failed to merge: 8 11
# failed to merge: 9 11
# .....
#
# 0.0, 0.0, 1.0
# 3 , 7
# ---
# 0.0, 0.0, -1.0
# 2 , 1
# ---
# -0.391304347826, -0.173913043478, -1.0
# 24 , 59
# ---
# 0.0, 1.0, 0.0
# 2 , 1
# ---
# 1.0, 0.0, -1.0
# 2 , 2
# ---
# 0.0, 0.181818181818, 0.636363636364
# 12 , 12
# ---
# -0.5, 0.0, -1.0
# 3 , 1
# ---
# 0.0, 0.0, 1.0
# 3 , 0
# ---
# 0.125, -0.375, -0.875
# 17 , 27
# ---
# 0.0, 0.0, -1.0
# 2 , 0
# ---
# num trajectories: 10
# old length 189
# all length 180
# orp length 9
# merged trj 2
# new length 0

# %%
plotEvent(run, "run.png")
